# %%
#Problem 1: Bank Account Create a class representing a bank account with attributes like account number, account holder name, and balance. Implement methods to deposit and withdraw money from the account.
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ${amount}. New balance is ${self.balance}.")
        else:
            print("Invalid deposit amount. Please enter a positive value.")
    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ${amount}. New balance is ${self.balance}.")
        else:
            print("Insufficient funds or invalid withdrawal amount.")
    def display_balance(self):
        print(f"Account Balance for {self.account_holder_name}: ${self.balance}")
my_account = BankAccount("123456789", "John Doe")
my_account.deposit(1000)
my_account.withdraw(500)
my_account.display_balance()
# Out:
# Deposited $1000. New balance is $1000.
# Withdrew $500. New balance is $500.
# Account Balance for John Doe: $500

# %%
#Problem 2: Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. Implement methods to calculate the yearly bonus and display employee details.
class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary
    def calculate_yearly_bonus(self, bonus_percentage):
        bonus = (bonus_percentage / 100) * self.salary
        return bonus
    def display_details(self):
        print("Employee Details:")
        print(f"Employee ID: {self.employee_id}")
        print(f"Name: {self.name}")
        print(f"Salary: ${self.salary}")
emp1 = Employee(101, "bheem", 50000)
emp1.display_details()
bonus_percentage = 10
yearly_bonus = emp1.calculate_yearly_bonus(bonus_percentage)
print(f"Yearly Bonus: ${yearly_bonus}")
# Out:
# Employee Details:
# Employee ID: 101
# Name: bheem
# Salary: $50000
# Yearly Bonus: $5000.0

# %%
#Problem 3: Vehicle Rental Create a class representing a vehicle rental system. Implement methods to rent a vehicle, return a vehicle, and display available vehicles.
class Vehicle:
    def __init__(self, make, model, year, available=True):
        self.make = make
        self.model = model
        self.year = year
        self.available = available
    def __str__(self):
        return f"{self.year} {self.make} {self.model}"
class RentalSystem:
    def __init__(self):
        self.vehicles = []
    def add_vehicle(self, vehicle):
        self.vehicles.append(vehicle)
    def rent_vehicle(self):
        available_vehicles = [v for v in self.vehicles if v.available]
        if not available_vehicles:
            print("Sorry, no vehicles available for rent.")
            return None
        else:
            print("Available vehicles for rent:")
            for i, vehicle in enumerate(available_vehicles, 1):
                print(f"{i}. {vehicle}")
            choice = int(input("Enter the number of the vehicle you want to rent: "))
            if choice < 1 or choice > len(available_vehicles):
                print("Invalid choice.")
                return None
            else:
                selected_vehicle = available_vehicles[choice - 1]
                selected_vehicle.available = False
                print(f"You have rented: {selected_vehicle}")
                return selected_vehicle
    def return_vehicle(self, returned_vehicle):
        for vehicle in self.vehicles:
            if vehicle.make == returned_vehicle.make and vehicle.model == returned_vehicle.model and vehicle.year == returned_vehicle.year:
                vehicle.available = True
                print(f"Thank you for returning the {returned_vehicle.year} {returned_vehicle.make} {returned_vehicle.model}.")
                return
        print("This vehicle does not belong to our rental system.")
    def display_available_vehicles(self):
        available_vehicles = [v for v in self.vehicles if v.available]
        if not available_vehicles:
            print("No vehicles available at the moment.")
        else:
            print("Available vehicles:")
            for vehicle in available_vehicles:
                print(vehicle)
rental_system = RentalSystem()
rental_system.add_vehicle(Vehicle("Toyota", "Camry", 2020))
rental_system.add_vehicle(Vehicle("Honda", "Civic", 2019))
rental_system.add_vehicle(Vehicle("Ford", "Escape", 2021))
rental_system.display_available_vehicles()
rented_vehicle = rental_system.rent_vehicle()
rental_system.display_available_vehicles()
if rented_vehicle:
    rental_system.return_vehicle(rented_vehicle)
    rental_system.display_available_vehicles()
# Out:
# Available vehicles:
# 2020 Toyota Camry
# 2019 Honda Civic
# 2021 Ford Escape
# Available vehicles for rent:
# 1. 2020 Toyota Camry
# 2. 2019 Honda Civic
# 3. 2021 Ford Escape
# Enter the number of the vehicle you want to rent: 1
# You have rented: 2020 Toyota Camry
# Available vehicles:
# 2019 Honda Civic
# 2021 Ford Escape
# Thank you for returning the 2020 Toyota Camry.
# Available vehicles:
# 2020 Toyota Camry
# 2019 Honda Civic
# 2021 Ford Escape

# %%
#Problem 4: Library Catalog Create classes representing a library and a book. Implement methods to add books to the library, borrow books, and display available books.
class Book:
    def __init__(self, title, author, available=True):
        self.title = title
        self.author = author
        self.available = available

    def __str__(self):
        return f"{self.title} by {self.author}"


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def borrow_book(self, title):
        for book in self.books:
            if book.title.lower() == title.lower() and book.available:
                book.available = False
                print(f"You have borrowed the book: {book}")
                return book
        print("Sorry, the book is either not available or not in the library.")
        return None

    def return_book(self, returned_book):
        for book in self.books:
            if book.title.lower() == returned_book.title.lower() and not book.available:
                book.available = True
                print(f"Thank you for returning the book: {returned_book}")
                return
        print("This book does not belong to our library or has not been borrowed.")

    def display_available_books(self):
        available_books = [book for book in self.books if book.available]
        if not available_books:
            print("No books available at the moment.")
        else:
            print("Available books:")
            for book in available_books:
                print(book)
library = Library()
library.add_book(Book("Harry Potter and the Sorcerer's Stone", "J.K. Rowling"))
library.add_book(Book("To Kill a Mockingbird", "Harper Lee"))
library.add_book(Book("The Great Gatsby", "F. Scott Fitzgerald"))
library.display_available_books()
borrowed_book = library.borrow_book("To Kill a Mockingbird")
library.display_available_books()
if borrowed_book:
    library.return_book(borrowed_book)
    library.display_available_books()
# Out:
# Available books:
# Harry Potter and the Sorcerer's Stone by J.K. Rowling
# To Kill a Mockingbird by Harper Lee
# The Great Gatsby by F. Scott Fitzgerald
# You have borrowed the book: To Kill a Mockingbird by Harper Lee
# Available books:
# Harry Potter and the Sorcerer's Stone by J.K. Rowling
# The Great Gatsby by F. Scott Fitzgerald
# Thank you for returning the book: To Kill a Mockingbird by Harper Lee
# Available books:
# Harry Potter and the Sorcerer's Stone by J.K. Rowling
# To Kill a Mockingbird by Harper Lee
# The Great Gatsby by F. Scott Fitzgerald

# %%
#Problem 5: Product Inventory Create classes representing a product and an inventory system. Implement methods to add products to the inventory, update product quantity, and display available products.
class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity
    def update_quantity(self, new_quantity):
        self.quantity = new_quantity
    def __str__(self):
        return f"Product ID: {self.product_id}, Name: {self.name}, Price: ${self.price}, Quantity: {self.quantity}"
class Inventory:
    def __init__(self):
        self.products = []
    def add_product(self, product):
        self.products.append(product)
    def update_product_quantity(self, product_id, new_quantity):
        for product in self.products:
            if product.product_id == product_id:
                product.update_quantity(new_quantity)
                print(f"Product quantity updated successfully for Product ID: {product_id}.")
                return
        print(f"Product with Product ID: {product_id} not found in the inventory.")
    def display_available_products(self):
        if not self.products:
            print("Inventory is empty.")
        else:
            print("Available Products:")
            for product in self.products:
                print(product)
inventory_system = Inventory()
inventory_system.add_product(Product(1, "Laptop", 800, 10))
inventory_system.add_product(Product(2, "Mouse", 20, 50))
inventory_system.add_product(Product(3, "Keyboard", 50, 30))
inventory_system.display_available_products()
inventory_system.update_product_quantity(2, 45)
inventory_system.display_available_products()
# Out:
# Available Products:
# Product ID: 1, Name: Laptop, Price: $800, Quantity: 10
# Product ID: 2, Name: Mouse, Price: $20, Quantity: 50
# Product ID: 3, Name: Keyboard, Price: $50, Quantity: 30
# Product quantity updated successfully for Product ID: 2.
# Available Products:
# Product ID: 1, Name: Laptop, Price: $800, Quantity: 10
# Product ID: 2, Name: Mouse, Price: $20, Quantity: 45
# Product ID: 3, Name: Keyboard, Price: $50, Quantity: 30

# %%
#Problem 6: Shape Calculation Create a class representing a shape with attributes like length, width, and height. Implement methods to calculate the area and perimeter of the shape.
class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height
    def calculate_area(self):
        raise NotImplementedError("Subclasses must implement calculate_area method")
    def calculate_perimeter(self):
        raise NotImplementedError("Subclasses must implement calculate_perimeter method")
class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width
    def calculate_perimeter(self):
        return 2 * (self.length + self.width)
class Square(Rectangle):
    def __init__(self, side):
        super().__init__(length=side, width=side)
    def calculate_perimeter(self):
        return 4 * self.length
class Triangle(Shape):
    def calculate_area(self):
        # Using Heron's formula to calculate the area of a triangle
        s = (self.length + self.width + self.height) / 2
        return (s * (s - self.length) * (s - self.width) * (s - self.height)) ** 0.5
    def calculate_perimeter(self):
        return self.length + self.width + self.height
rectangle = Rectangle(length=5, width=3)
print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())
square = Square(side=4)
print("Square Area:", square.calculate_area())
print("Square Perimeter:", square.calculate_perimeter())
triangle = Triangle(length=3, width=4, height=5)
print("Triangle Area:", triangle.calculate_area())
print("Triangle Perimeter:", triangle.calculate_perimeter())
# Out:
# Rectangle Area: 15
# Rectangle Perimeter: 16
# Square Area: 16
# Square Perimeter: 16
# Triangle Area: 6.0
# Triangle Perimeter: 12

# %%
#Problem 7: Student Management Create a class representing a student with attributes like student ID, name, and grades. Implement methods to calculate the average grade and display student details.#
class Student:
    def __init__(self, student_id, name):
        self.student_id = student_id
        self.name = name
        self.grades = []
    def add_grade(self, grade):
        self.grades.append(grade)
    def calculate_average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)
    def display_details(self):
        print("Student ID:", self.student_id)
        print("Name:", self.name)
        print("Grades:", self.grades)
        print("Average Grade:", self.calculate_average_grade())
student1 = Student("s014", "Mallesh")
student1.add_grade(85)
student1.add_grade(90)
student1.add_grade(75)
student1.display_details()
# Out:
# Student ID: s014
# Name: Mallesh
# Grades: [85, 90, 75]
# Average Grade: 83.33333333333333

# %%
#Problem 8: Email Management Create a class representing an email with attributes like sender, recipient, and subject. Implement methods to send an email and display email details.
class Email:
    def __init__(self, sender, recipient, subject, message):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.message = message
    def send_email(self):
        print(f"Email sent from: {self.sender}")
        print(f"Email sent to: {self.recipient}")
        print(f"Subject: {self.subject}")
        print("Message:")
        print(self.message)
    def display_details(self):
        print("Sender:", self.sender)
        print("Recipient:", self.recipient)
        print("Subject:", self.subject)
        print("Message:", self.message)
email = Email(sender="user@example.com", recipient="recipient@example.com", subject="Test Email", message="Hello, this is a test email!")
email.display_details()
email.send_email()
# Out:
# Sender: user@example.com
# Recipient: recipient@example.com
# Subject: Test Email
# Message: Hello, this is a test email!
# Email sent from: user@example.com
# Email sent to: recipient@example.com
# Subject: Test Email
# Message:
# Hello, this is a test email!

# %%
#Problem 9: Social Media Profile Create a class representing a social media profile with attributes like username and posts. Implement methods to add posts, display posts, and search for posts by keyword.
class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []
    def add_post(self, post):
        self.posts.append(post)
    def display_posts(self):
        if not self.posts:
            print("No posts available.")
        else:
            print(f"Posts by {self.username}:")
            for i, post in enumerate(self.posts, 1):
                print(f"{i}. {post}")
    def search_posts(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post.lower()]
        if not matching_posts:
            print(f"No posts found containing '{keyword}'.")
        else:
            print(f"Posts containing '{keyword}':")
            for i, post in enumerate(matching_posts, 1):
                print(f"{i}. {post}")
profile = SocialMediaProfile(username="user123")
profile.add_post("Hello, this is my first post!")
profile.add_post("Just finished a great book!")
profile.add_post("Enjoying the weather today.")
profile.display_posts()
profile.search_posts("great")
# Out:
# Posts by user123:
# 1. Hello, this is my first post!
# 2. Just finished a great book!
# 3. Enjoying the weather today.
# Posts containing 'great':
# 1. Just finished a great book!

# %%
#Problem 10: ToDo List Create a class representing a ToDo list with attributes like tasks and due dates. Implement methods to add tasks, mark tasks as completed, and display pending tasks.
class ToDoList:
    def __init__(self):
        self.tasks = {}
    def add_task(self, task, due_date):
        self.tasks[task] = due_date
    def mark_task_completed(self, task):
        if task in self.tasks:
            del self.tasks[task]
            print(f"Task '{task}' marked as completed.")
        else:
            print(f"Task '{task}' not found in the ToDo list.")
    def display_pending_tasks(self):
        if not self.tasks:
            print("No pending tasks.")
        else:
            print("Pending tasks:")
            for task, due_date in self.tasks.items():
                print(f"{task} - Due Date: {due_date}")
todo_list = ToDoList()
todo_list.add_task("Complete project proposal", "2024-04-05")
todo_list.add_task("Buy groceries", "2024-04-08")
todo_list.add_task("Call client", "2024-04-10")
todo_list.display_pending_tasks()
todo_list.mark_task_completed("Buy groceries")
todo_list.display_pending_tasks()
# Out:
# Pending tasks:
# Complete project proposal - Due Date: 2024-04-05
# Buy groceries - Due Date: 2024-04-08
# Call client - Due Date: 2024-04-10
# Task 'Buy groceries' marked as completed.
# Pending tasks:
# Complete project proposal - Due Date: 2024-04-05
# Call client - Due Date: 2024-04-10
