# %%
#1 Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`. After generating the list, find the following:
#(i) Write a Python function to calculate the mean of a given list of numbers.Create a function to find the median of a list of numbers.
#(ii) Develop a program to compute the mode of a list of integers.
#(iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights.
#(iv) Write a Python function to find the geometric mean of a list of positive numbers.
#(v) Create a program to calculate the harmonic mean of a list of values.
#(vi) Build a function to determine the midrange of a list of numbers (average of the minimum and maximum).
#(vii) Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of outliers.

import random
import statistics
import numpy as np
from scipy import stats
from typing import List

# Generate the list of 100 integers between 90 and 130
int_list = [random.randint(90, 130) for _ in range(100)]
print(int_list)

# (i) Mean Calculation
def calculate_mean(numbers: List[int]) -> float:
    return sum(numbers) / len(numbers)

# Median Calculation
def calculate_median(numbers: List[int]) -> float:
    sorted_numbers = sorted(numbers)
    n = len(sorted_numbers)
    if n % 2 == 0:
        median = (sorted_numbers[n // 2 - 1] + sorted_numbers[n // 2]) / 2
    else:
        median = sorted_numbers[n // 2]
    return median

# (ii) Mode Calculation
def calculate_mode(numbers: List[int]) -> int:
    return statistics.mode(numbers)

# (iii) Weighted Mean Calculation
def calculate_weighted_mean(values: List[int], weights: List[int]) -> float:
    weighted_sum = sum(value * weight for value, weight in zip(values, weights))
    total_weight = sum(weights)
    return weighted_sum / total_weight

# (iv) Geometric Mean Calculation
def calculate_geometric_mean(numbers: List[int]) -> float:
    product = 1
    for number in numbers:
        product *= number
    return product ** (1 / len(numbers))

# (v) Harmonic Mean Calculation
def calculate_harmonic_mean(numbers: List[int]) -> float:
    return len(numbers) / sum(1 / number for number in numbers)

# (vi) Midrange Calculation
def calculate_midrange(numbers: List[int]) -> float:
    return (max(numbers) + min(numbers)) / 2

# (vii) Trimmed Mean Calculation
def calculate_trimmed_mean(numbers: List[int], percentage: float) -> float:
    return stats.trim_mean(numbers, proportiontocut=percentage)

# Example usage
mean = calculate_mean(int_list)
median = calculate_median(int_list)
mode = calculate_mode(int_list)
# For weighted mean, we need weights. Let's generate random weights
weights = [random.randint(1, 10) for _ in range(100)]
weighted_mean = calculate_weighted_mean(int_list, weights)
geometric_mean = calculate_geometric_mean(int_list)
harmonic_mean = calculate_harmonic_mean(int_list)
midrange = calculate_midrange(int_list)
trimmed_mean = calculate_trimmed_mean(int_list, 0.1)  # 10% trimmed mean

# Print results
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Weighted Mean: {weighted_mean}")
print(f"Geometric Mean: {geometric_mean}")
print(f"Harmonic Mean: {harmonic_mean}")
print(f"Midrange: {midrange}")
print(f"Trimmed Mean: {trimmed_mean}")
# Out:
# [91, 111, 115, 103, 92, 121, 126, 120, 117, 118, 124, 107, 93, 118, 106, 90, 116, 116, 124, 115, 116, 93, 98, 93, 109, 95, 130, 122, 114, 107, 108, 117, 130, 125, 105, 98, 111, 120, 109, 117, 118, 114, 103, 94, 119, 113, 91, 117, 128, 122, 130, 92, 108, 92, 91, 123, 105, 120, 128, 103, 110, 99, 128, 114, 96, 120, 102, 129, 124, 92, 116, 115, 95, 101, 111, 94, 115, 103, 106, 118, 128, 130, 105, 108, 100, 106, 90, 93, 124, 114, 96, 121, 122, 115, 91, 108, 125, 112, 110, 109]
# Mean: 110.46
# Median: 111.5
# Mode: 115
# Weighted Mean: 109.76491862567812
# Geometric Mean: 109.81643688180642
# Harmonic Mean: 109.16108027743113
# Midrange: 110.0
# Trimmed Mean: 110.5875

# %%
#2. Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`.After generating the list, find the following:

#(i) Compare the given list of visualization for the given data:

    #1. Frequency & Gaussian distribution

    #2. Frequency smoothened KDE plot

    #3. Gaussian distribution & smoothened KDE plot write exact code
    
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate 500 integers between 200 and 300
int_list2 = np.random.randint(200, 301, 500)
print(int_list2)
# Plotting the distribution
plt.figure(figsize=(12, 6))

# Plot 1: Frequency plot
plt.subplot(2, 2, 1)
sns.histplot(int_list2, bins=20, kde=False, color='blue', edgecolor='black')
plt.title('Frequency Plot')
plt.xlabel('Values')
plt.ylabel('Frequency')

# Plot 2: Gaussian distribution (assuming mean and std of the data)
plt.subplot(2, 2, 2)
sns.histplot(int_list2, bins=20, kde=True, color='orange', edgecolor='black', stat='density')
plt.title('Gaussian Distribution')
plt.xlabel('Values')
plt.ylabel('Density')

# Plot 3: Smoothed KDE plot
plt.subplot(2, 2, 3)
sns.kdeplot(int_list2, color='green', linewidth=2)
plt.title('Smoothed KDE Plot')
plt.xlabel('Values')
plt.ylabel('Density')

# Plot 4: Comparison plot
plt.subplot(2, 2, 4)
sns.histplot(int_list2, bins=20, kde=False, color='blue', edgecolor='black', label='Frequency')
sns.histplot(int_list2, bins=20, kde=True, color='orange', edgecolor='black', stat='density', label='Gaussian')
sns.kdeplot(int_list2, color='green', linewidth=2, label='KDE')
plt.title('Comparison of Plots')
plt.xlabel('Values')
plt.ylabel('Density')
plt.legend()

plt.tight_layout()
plt.show()

  #(ii) Write a Python function to calculate the range of a given list of numbers.
def calculate_range(nums):
    return max(nums) - min(nums)

# Example usage:
range_of_int_list2 = calculate_range(int_list2)
print(f"Range of int_list2: {range_of_int_list2}")


  #(iii) Create a program to find the variance and standard deviation of a list of numbers.
def calculate_variance_and_stddev(nums):
    mean = np.mean(nums)
    variance = np.var(nums)
    stddev = np.std(nums)
    return variance, stddev

# Example usage:
variance_int_list2, stddev_int_list2 = calculate_variance_and_stddev(int_list2)
print(f"Variance of int_list2: {variance_int_list2}")
print(f"Standard Deviation of int_list2: {stddev_int_list2}")


  #(iv) Implement a function to compute the interquartile range (IQR) of a list of values.
def calculate_iqr(nums):
    q75, q25 = np.percentile(nums, [75 ,25])
    return q75 - q25

# Example usage:
iqr_int_list2 = calculate_iqr(int_list2)
print(f"IQR of int_list2: {iqr_int_list2}")
    
#(v) Build a program to calculate the coefficient of variation for a dataset.
def calculate_coefficient_of_variation(nums):
    mean = np.mean(nums)
    stddev = np.std(nums)
    return (stddev / mean) * 100  # Multiply by 100 to get percentage

# Example usage:
cv_int_list2 = calculate_coefficient_of_variation(int_list2)
print(f"Coefficient of Variation of int_list2: {cv_int_list2}%")


  #(vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.
def calculate_mean_absolute_deviation(nums):
    mean = np.mean(nums)
    mad = np.mean(np.abs(nums - mean))
    return mad

# Example usage:
mad_int_list2 = calculate_mean_absolute_deviation(int_list2)
print(f"Mean Absolute Deviation of int_list2: {mad_int_list2}")


  #(vii) Create a program to calculate the quartile deviation of a list of values.
def calculate_quartile_deviation(nums):
    q75, q25 = np.percentile(nums, [75 ,25])
    return (q75 - q25) / 2

# Example usage:
qd_int_list2 = calculate_quartile_deviation(int_list2)
print(f"Quartile Deviation of int_list2: {qd_int_list2}")


  #(viii) Implement a function to find the range-based coefficient of dispersion for a dataset.
def calculate_range_based_cod(nums):
    range_val = max(nums) - min(nums)
    mean = np.mean(nums)
    return (range_val / mean) * 100  # Multiply by 100 to get percentage

# Example usage:
cod_int_list2 = calculate_range_based_cod(int_list2)
print(f"Range-based Coefficient of Dispersion of int_list2: {cod_int_list2}%")
# Out:
# [256 265 249 243 239 237 224 250 293 250 295 244 236 266 283 259 253 255
#  205 279 283 202 247 295 214 297 222 244 286 221 263 270 279 247 200 296
#  216 236 290 287 251 257 290 231 212 208 262 224 278 284 245 239 243 262
#  207 240 297 244 213 269 226 214 298 220 227 250 231 283 252 258 232 212
#  210 214 202 300 217 250 204 225 245 224 242 229 231 287 282 251 212 219
#  248 269 203 295 239 201 240 295 229 275 224 222 229 289 242 207 201 229
#  248 252 239 287 262 292 258 275 220 216 205 238 219 291 282 244 299 221
#  214 286 247 201 228 240 211 222 202 225 234 214 249 218 256 242 226 227
#  275 252 212 240 273 277 244 241 204 245 247 240 292 255 256 218 264 204
#  208 250 228 209 232 291 250 202 209 236 231 260 234 208 239 286 243 267
#  267 206 256 294 249 254 223 256 281 217 288 232 200 247 281 269 206 268
#  232 241 249 256 262 212 235 252 235 222 215 214 233 242 208 224 270 260
#  297 275 257 201 265 214 271 268 230 267 218 214 226 221 288 254 263 243
# ...

# %%
#3 Write a Python class representing a discrete random variable with methods to calculate its expected value and variance.
class DiscreteRandomVariable:
    def __init__(self, outcomes, probabilities):
        """
        Initialize a discrete random variable with outcomes and corresponding probabilities.

        :param outcomes: List or tuple of outcomes.
        :param probabilities: List or tuple of probabilities corresponding to outcomes.
        """
        if len(outcomes) != len(probabilities):
            raise ValueError("Lengths of outcomes and probabilities must be the same.")
        
        self.outcomes = outcomes
        self.probabilities = probabilities

    def expected_value(self):
        """
        Calculate the expected value (mean) of the discrete random variable.

        :return: Expected value of the discrete random variable.
        """
        expected_value = sum(x * p for x, p in zip(self.outcomes, self.probabilities))
        return expected_value

    def variance(self):
        """
        Calculate the variance of the discrete random variable.

        :return: Variance of the discrete random variable.
        """
        mean = self.expected_value()
        variance = sum(p * (x - mean)**2 for x, p in zip(self.outcomes, self.probabilities))
        return variance

# Example usage:
outcomes = [1, 2, 3, 4, 5, 6]  # Example outcomes of a dice roll
probabilities = [1/6, 1/6, 1/6, 1/6, 1/6, 1/6]  # Example probabilities for a fair dice
dice_variable = DiscreteRandomVariable(outcomes, probabilities)

print("Expected value:", dice_variable.expected_value())
print("Variance:", dice_variable.variance())
# Out:
# Expected value: 3.5
# Variance: 2.9166666666666665

# %%
#4 Implement a program to simulate the rolling o6 a 6air six-sided die and calculate the expected value and variance o6 the outcomes.
import random
import statistics

# Function to simulate rolling a fair six-sided die
def roll_die():
    return random.randint(1, 6)

# Number of simulations
num_simulations = 100000

# List to store outcomes of simulations
outcomes = []

# Simulate rolling the die num_simulations times
for _ in range(num_simulations):
    outcome = roll_die()
    outcomes.append(outcome)

# Calculate the expected value
expected_value = sum(outcomes) / num_simulations

# Calculate the variance
variance = statistics.variance(outcomes)

# Print results
print(f"Number of simulations: {num_simulations}")
print(f"Expected value: {expected_value}")
print(f"Variance: {variance}")
# Out:
# Number of simulations: 100000
# Expected value: 3.49438
# Variance: 2.9049574651746517

# %%
#5 Create a Python function to generate random samples from a given probability distribution (e.g.,binomial, Poisson) and calculate their mean and variance.

import numpy as np

def generate_samples_distribution(distribution, params, sample_size):
    """
    Generate random samples from a given probability distribution and calculate mean and variance.

    Parameters:
    - distribution: A string indicating the distribution ('binomial' or 'poisson').
    - params: A tuple containing parameters specific to the distribution:
        - For 'binomial': (n, p) where n is the number of trials and p is the probability of success.
        - For 'poisson': (lam,) where lam is the rate parameter.
    - sample_size: Number of samples to generate.

    Returns:
    - mean: Mean of the generated samples.
    - variance: Variance of the generated samples.
    """
    if distribution == 'binomial':
        n, p = params
        samples = np.random.binomial(n, p, sample_size)
    elif distribution == 'poisson':
        lam = params[0]
        samples = np.random.poisson(lam, sample_size)
    else:
        raise ValueError("Unsupported distribution. Choose 'binomial' or 'poisson'.")

    mean = np.mean(samples)
    variance = np.var(samples)

    return mean, variance

# Example usage:

# Generate samples from a binomial distribution with n=10, p=0.5
mean_binomial, var_binomial = generate_samples_distribution('binomial', (10, 0.5), 10000)
print(f"Binomial distribution: Mean = {mean_binomial}, Variance = {var_binomial}")

# Generate samples from a Poisson distribution with lambda=3.0
mean_poisson, var_poisson = generate_samples_distribution('poisson', (3.0,), 10000)
print(f"Poisson distribution: Mean = {mean_poisson}, Variance = {var_poisson}")
# Out:
# Binomial distribution: Mean = 5.0001, Variance = 2.4434999900000003
# Poisson distribution: Mean = 2.9925, Variance = 2.95944375

# %%
#6 Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation of the samples.
import numpy as np

def generate_normal_samples(mean, std_dev, sample_size):
    """
    Generate random samples from a Gaussian (normal) distribution and calculate mean, variance, and standard deviation.

    Parameters:
    - mean: Mean of the normal distribution.
    - std_dev: Standard deviation of the normal distribution.
    - sample_size: Number of samples to generate.

    Returns:
    - mean_sample: Mean of the generated samples.
    - variance_sample: Variance of the generated samples.
    - std_dev_sample: Standard deviation of the generated samples.
    """
    samples = np.random.normal(mean, std_dev, sample_size)
    mean_sample = np.mean(samples)
    variance_sample = np.var(samples)
    std_dev_sample = np.std(samples)

    return mean_sample, variance_sample, std_dev_sample

# Example usage:

mean = 0    # Mean of the normal distribution
std_dev = 1 # Standard deviation of the normal distribution
sample_size = 10000

mean_sample, variance_sample, std_dev_sample = generate_normal_samples(mean, std_dev, sample_size)

print(f"Generated normal distribution with mean = {mean}, std_dev = {std_dev}, sample_size = {sample_size}:")
print(f"Mean: {mean_sample}")
print(f"Variance: {variance_sample}")
print(f"Standard Deviation: {std_dev_sample}")
# Out:
# Generated normal distribution with mean = 0, std_dev = 1, sample_size = 10000:
# Mean: -0.02129446874616618
# Variance: 0.9877331697197904
# Standard Deviation: 0.9938476592113051

# %%
#7 Use seaborn library to load tips dataset. Find the following from the dataset for the columns total_bill and tip`:
import seaborn as sns
import pandas as pd
import numpy as np
from scipy.stats import skew
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")
tips

#(i) Write a Python function that calculates their skewness.
def calculate_skewness(column):
    return skew(column)

# Calculate skewness for 'total_bill' and 'tip'
total_bill_skewness = calculate_skewness(tips['total_bill'])
tip_skewness = calculate_skewness(tips['tip'])

print(f"Skewness of total_bill: {total_bill_skewness}")
print(f"Skewness of tip: {tip_skewness}")


#(ii) Create a program that determines whether the columns exhibit positive skewness, negative skewness, or is approximately symmetric.
def skewness_type(skewness_value):
    if skewness_value > 0:
        return "Positive Skewness"
    elif skewness_value < 0:
        return "Negative Skewness"
    else:
        return "Approximately Symmetric"

# Determine skewness type for 'total_bill' and 'tip'
total_bill_skewness_type = skewness_type(total_bill_skewness)
tip_skewness_type = skewness_type(tip_skewness)

print(f"Total_bill column is {total_bill_skewness_type}")
print(f"Tip column is {tip_skewness_type}")

#(iii) Write a function that calculates the covariance between two columns.
def calculate_covariance(column1, column2):
    return np.cov(column1, column2)[0, 1]

# Calculate covariance between 'total_bill' and 'tip'
covariance = calculate_covariance(tips['total_bill'], tips['tip'])

print(f"Covariance between total_bill and tip: {covariance}")


#(iv) Implement a Python program that calculates the Pearson correlation coefficient between two columns.
def calculate_pearson_correlation(column1, column2):
    return np.corrcoef(column1, column2)[0, 1]

# Calculate Pearson correlation coefficient between 'total_bill' and 'tip'
pearson_correlation = calculate_pearson_correlation(tips['total_bill'], tips['tip'])

print(f"Pearson correlation coefficient between total_bill and tip: {pearson_correlation}")


#(v) Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using scatter plot.
def plot_scatter(data, column1, column2):
    """
    Plot a scatter plot to visualize the correlation between two specified columns in the DataFrame.
    
    Parameters:
    data (pd.DataFrame): The DataFrame containing the data.
    column1 (str): The name of the first column.
    column2 (str): The name of the second column.
    """
    plt.figure(figsize=(8, 6))
    plt.scatter(data[column1], data[column2], alpha=0.5)
    plt.title(f'Scatter Plot of {column1} vs {column2}')
    plt.xlabel(column1)
    plt.ylabel(column2)
    plt.grid(True)
    plt.show()

# Plot scatter plot for 'total_bill' and 'tip'
plot_scatter(tips, 'total_bill', 'tip')
# Out:
# Skewness of total_bill: 1.1262346334818638
# Skewness of tip: 1.4564266884221506
# Total_bill column is Positive Skewness
# Tip column is Positive Skewness
# Covariance between total_bill and tip: 8.323501629224854
# Pearson correlation coefficient between total_bill and tip: 0.6757341092113646

# %%
#8 Write a Python function to calculate the probability density function (PDF) o6 a continuous random variable for a given normal distribution.
import numpy as np

def normal_pdf(x, mu, sigma):
    """
    Calculate the PDF of a normal distribution at a given value x.
    
    Parameters:
    x (float): The value at which to evaluate the PDF.
    mu (float): The mean of the normal distribution.
    sigma (float): The standard deviation of the normal distribution.
    
    Returns:
    float: The PDF value at x.
    """
    coefficient = 1 / (np.sqrt(2 * np.pi) * sigma)
    exponent = np.exp(-((x - mu) ** 2) / (2 * sigma ** 2))
    return coefficient * exponent

# Example usage
x_value = 1.0
mean = 0.0
std_dev = 1.0

pdf_value = normal_pdf(x_value, mean, std_dev)
pdf_value
# Out:
# 0.24197072451914337

# %%
#9 Create a program to calculate the cumulative distribution function (CDF) of exponential distribution.
import numpy as np

def exponential_cdf(x, lam):
    """
    Calculate the CDF of an exponential distribution at a given value x.
    
    Parameters:
    x (float): The value at which to evaluate the CDF.
    lam (float): The rate parameter (lambda) of the exponential distribution.
    
    Returns:
    float: The CDF value at x.
    """
    if x < 0:
        return 0.0
    return 1 - np.exp(-lam * x)

# Example usage
x_value = 1.0
rate_param = 0.5

cdf_value = exponential_cdf(x_value, rate_param)
cdf_value
# Out:
# 0.3934693402873666

# %%
#10 Write a Python 6unction to calculate the probability mass function (PMF) of Poisson distribution.
import numpy as np
import math

def poisson_pmf(k, lam):
    """
    Calculate the PMF of a Poisson distribution for a given number of occurrences k.
    
    Parameters:
    k (int): The number of occurrences.
    lam (float): The average rate (lambda) of occurrences.
    
    Returns:
    float: The PMF value for k occurrences.
    """
    if k < 0 or not isinstance(k, int):
        raise ValueError("k must be a non-negative integer.")
    return (lam ** k * np.exp(-lam)) / math.factorial(k)

# Example usage
k_value = 3
rate_param = 2.0

pmf_value = poisson_pmf(k_value, rate_param)
pmf_value
# Out:
# 0.1804470443154836

# %%
#11 A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors who make a purchase). 
#They collect data from the old and new layouts to compare To generate the data use the following command:

"""python

import numpy as np

# 50 purchases out of 1000 visitors

old_layout = np.array([1] * 50 + [0] * 950)

# 70 purchases out of 1000 visitors  
new_layout = np.array([1] * 70 + [0] * 930)
  ```
Apply z-test to find which layout is successful"""

import numpy as np
from scipy.stats import norm

# Generate the data
old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)

# Conversion rates
p1 = np.mean(old_layout)
p2 = np.mean(new_layout)

# Sample sizes
n1 = len(old_layout)
n2 = len(new_layout)

# Pooled proportion
p_hat = (np.sum(old_layout) + np.sum(new_layout)) / (n1 + n2)

# Standard Error
SE = np.sqrt(p_hat * (1 - p_hat) * (1/n1 + 1/n2))

# Z-score
z = (p2 - p1) / SE

# p-value (one-tailed test)
p_value = 1 - norm.cdf(z)

p1, p2, z, p_value
# Out:
# (0.05, 0.07, 1.883108942886774, 0.029842802766213095)

# %%
#12 A tutoring service claims that its program improves students' exam scores. A sample of students who participated in the program was taken, and their scores before and after the program were recorded.
"""Use the below code to generate samples of respective arrays of marks:
python
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])
Use z-test to find if the claims made by tutor are true or false"""

import numpy as np
from scipy import stats

# Sample data
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

# Step 2: Calculate the differences
differences = after_program - before_program

# Step 3: Calculate the mean and standard deviation of the differences
mean_difference = np.mean(differences)
std_difference = np.std(differences, ddof=1)

# Step 4: Calculate the test statistic
n = len(differences)
z = mean_difference / (std_difference / np.sqrt(n))

# Step 5: Find the critical value for a one-tailed test at alpha = 0.05
alpha = 0.05
critical_value = stats.norm.ppf(1 - alpha)

# Output the results
mean_difference, std_difference, z, critical_value
# Out:
# (3.8, 2.616188916046478, 4.593190894944668, 1.6448536269514722)

# %%
#13 A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and aNter administering the drug.
"""Use the below code to generate samples of respective arrays of blood pressure:
python
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])
Implement z-test to find if the drug really works or not."""
import numpy as np
from scipy import stats

# Sample data
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

# Step 2: Calculate the differences
differences = after_drug - before_drug

# Step 3: Calculate the mean and standard deviation of the differences
mean_difference = np.mean(differences)
std_difference = np.std(differences, ddof=1)

# Step 4: Calculate the test statistic
n = len(differences)
z = mean_difference / (std_difference / np.sqrt(n))

# Step 5: Find the critical value for a one-tailed test at alpha = 0.05
alpha = 0.05
critical_value = stats.norm.ppf(alpha)

# Output the results
mean_difference, std_difference, z, critical_value
# Out:
# (-10.1, 3.178049716414141, -10.049875621120888, -1.6448536269514729)

# %%
#14 A customer service department claims that their average response time is less than 5 minutes A sample of recent customer interactions was taken, and the response times were recorded.
#Implement the below code to generate the array of response time:
"""python
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])
Implement z-test to find the claims made by customer service department are true or false."""

import numpy as np
from scipy import stats

# Sample data
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])

# Step 2: Calculate the sample mean and standard deviation
sample_mean = np.mean(response_times)
sample_std = np.std(response_times, ddof=1)

# Step 3: Calculate the test statistic
n = len(response_times)
mu = 5  # Claimed population mean
z = (sample_mean - mu) / (sample_std / np.sqrt(n))

# Step 4: Find the critical value for a one-tailed test at alpha = 0.05
alpha = 0.05
critical_value = stats.norm.ppf(alpha)

# Output the results
sample_mean, sample_std, z, critical_value
# Out:
# (4.57, 0.4270050741306634, -3.184457226042963, -1.6448536269514729)

# %%
#15 A company is testing two different website layouts to see which one leads to higher click-through rates
#Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value.
"""Use the following data:
python
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]"""

import numpy as np
from scipy import stats

def ab_test(layout_a_clicks, layout_b_clicks):
    # Calculate the sample means
    mean_a = np.mean(layout_a_clicks)
    mean_b = np.mean(layout_b_clicks)
    
    # Calculate the sample standard deviations
    std_a = np.std(layout_a_clicks, ddof=1)
    std_b = np.std(layout_b_clicks, ddof=1)
    
    # Calculate the sample sizes
    n_a = len(layout_a_clicks)
    n_b = len(layout_b_clicks)
    
    # Calculate the pooled standard deviation
    pooled_std = np.sqrt(((std_a ** 2) / n_a) + ((std_b ** 2) / n_b))
    
    # Calculate the t-statistic
    t_statistic = (mean_a - mean_b) / pooled_std
    
    # Calculate the degrees of freedom
    df = n_a + n_b - 2
    
    # Calculate the p-value
    p_value = stats.t.sf(np.abs(t_statistic), df) * 2  # two-tailed test
    
    return t_statistic, df, p_value

# Sample data
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

# Perform the A/B test
t_statistic, df, p_value = ab_test(layout_a_clicks, layout_b_clicks)

# Output the results
t_statistic, df, p_value
# Out:
# (-7.298102156175071, 18, 8.833437608301987e-07)

# %%
#17 A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in
#reducing cholesterol levels Create a program to analyze the clinical trial data and calculate the statistic and p-value for the treatment effect.
"""Use the following data of cholestrol level:
python
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]"""

import numpy as np
from scipy import stats

def drug_effectiveness_test(existing_drug_levels, new_drug_levels):
    # Calculate means and standard deviations
    mean_existing = np.mean(existing_drug_levels)
    mean_new = np.mean(new_drug_levels)
    
    std_existing = np.std(existing_drug_levels, ddof=1)
    std_new = np.std(new_drug_levels, ddof=1)
    
    n_existing = len(existing_drug_levels)
    n_new = len(new_drug_levels)
    
    # Calculate the t-statistic
    t_statistic = (mean_new - mean_existing) / np.sqrt((std_new**2 / n_new) + (std_existing**2 / n_existing))
    
    # Calculate the degrees of freedom
    df = ((std_new**2 / n_new) + (std_existing**2 / n_existing))**2 / ((std_new**2 / n_new)**2 / (n_new - 1) + (std_existing**2 / n_existing)**2 / (n_existing - 1))
    
    # Calculate the p-value
    p_value = stats.t.cdf(t_statistic, df)
    
    return t_statistic, df, p_value

# Sample data
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

# Perform the test
t_statistic, df, p_value = drug_effectiveness_test(existing_drug_levels, new_drug_levels)

# Output the results
t_statistic, df, p_value
# Out:
# (-4.140480986208661, 17.866770765582338, 0.00031146144727346535)

# %%
#18 A school district introduces an educational intervention program to improve math scores Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p value to determine if the intervention had a significant impact.
"""Use the following data of test score:
  ```python
  pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
  post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]"""

import numpy as np
from scipy import stats

def paired_t_test(pre_scores, post_scores):
    # Calculate the differences
    differences = np.array(post_scores) - np.array(pre_scores)
    
    # Calculate mean and standard deviation of the differences
    mean_diff = np.mean(differences)
    std_diff = np.std(differences, ddof=1)
    
    # Sample size
    n = len(differences)
    
    # Calculate the t-statistic
    t_statistic = mean_diff / (std_diff / np.sqrt(n))
    
    # Degrees of freedom
    df = n - 1
    
    # Calculate the p-value
    p_value = stats.t.sf(np.abs(t_statistic), df) * 2  # two-tailed test
    
    return t_statistic, df, p_value

# Sample data
pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

# Perform the paired t-test
t_statistic, df, p_value = paired_t_test(pre_intervention_scores, post_intervention_scores)

# Output the results
t_statistic, df, p_value
# Out:
# (4.428408839657611, 9, 0.0016509548165795493)

# %%
#19 An HR department wants to investigate if there's a gender-based salary gap within the company. Develop a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically significant difference between the average salaries of male and female employees.
#Use the below code to generate synthetic data
"""python
# Generate synthetic salary data for male and female employees
np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)"""

import numpy as np
from scipy import stats

# Generate synthetic salary data for male and female employees
np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

def gender_salary_gap_test(male_salaries, female_salaries):
    # Calculate means and standard deviations
    mean_male = np.mean(male_salaries)
    mean_female = np.mean(female_salaries)
    
    std_male = np.std(male_salaries, ddof=1)
    std_female = np.std(female_salaries, ddof=1)
    
    n_male = len(male_salaries)
    n_female = len(female_salaries)
    
    # Calculate the t-statistic
    t_statistic = (mean_male - mean_female) / np.sqrt((std_male**2 / n_male) + (std_female**2 / n_female))
    
    # Calculate the degrees of freedom
    df = ((std_male**2 / n_male) + (std_female**2 / n_female))**2 / ((std_male**2 / n_male)**2 / (n_male - 1) + (std_female**2 / n_female)**2 / (n_female - 1))
    
    # Calculate the p-value
    p_value = stats.t.sf(np.abs(t_statistic), df) * 2  # two-tailed test
    
    return t_statistic, df, p_value

# Perform the gender salary gap test
t_statistic, df, p_value = gender_salary_gap_test(male_salaries, female_salaries)

# Output the results
t_statistic, df, p_value
# Out:
# (0.061142089696313844, 36.166783312917644, 0.9515826849267927)

# %%
#20 A restaurant chain collects customer satisfaction scores for two different branches. Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in customer satisfaction between the branches.
"""Use the below data of scores:
python
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]"""

import numpy as np
from scipy import stats

# Data
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

# Calculate the t-statistic and p-value
t_statistic, p_value = stats.ttest_ind(branch_a_scores, branch_b_scores)

# Output the results
print(f"T-Statistic: {t_statistic}")
print(f"P-Value: {p_value}")

# Interpret the results
alpha = 0.05  # significance level
if p_value < alpha:
    print("There is a statistically significant difference in customer satisfaction between the branches.")
else:
    print("There is no statistically significant difference in customer satisfaction between the branches.")
# Out:
# T-Statistic: 5.480077554195743
# P-Value: 8.895290509945655e-07
# There is a statistically significant difference in customer satisfaction between the branches.

# %%
#21 A political analyst wants to determine if there is a significant association between age groups and voter preferences (Candidate A or Candidate B). They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences. Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences.
"""Use the below code to generate data:
```python
np.random.seed(0)
age_groups = np.random.choice([ 18 30 , 31 50 , 51+', 51+'], size=30)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)"""

import numpy as np
from scipy.stats import chi2_contingency

np.random.seed(0)

# Generate random data
age_groups = np.random.choice(['18-30', '31-50', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

# Create a contingency table (cross-tabulation)
contingency_table = np.zeros((3, 2), dtype=int)

for i in range(len(age_groups)):
    if age_groups[i] == '18-30':
        row = 0
    elif age_groups[i] == '31-50':
        row = 1
    elif age_groups[i] == '51+':
        row = 2
    
    if voter_preferences[i] == 'Candidate A':
        col = 0
    elif voter_preferences[i] == 'Candidate B':
        col = 1
    
    contingency_table[row, col] += 1

print("Contingency Table:")
print(contingency_table)

# Perform Chi-Square test
chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)

print("\nChi-Square Statistic:", chi2_stat)
print("P-Value:", p_val)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)

# Interpret the results
alpha = 0.05
if p_val < alpha:
    print("\nThere is a significant association between age groups and voter preferences.")
else:
    print("\nThere is no significant association between age groups and voter preferences.")
# Out:
# Contingency Table:
# [[95 87]
#  [87 82]
#  [84 65]]
#
# Chi-Square Statistic: 0.8779923945254768
# P-Value: 0.6446832311860852
# Degrees of Freedom: 2
# Expected Frequencies:
# [[96.824 85.176]
#  [89.908 79.092]
#  [79.268 69.732]]
#
# There is no significant association between age groups and voter preferences.

# %%
#22 A company conducted a customer satisfaction survey to determine if there is a significant relationship between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are located (East, West, North, South). The survey data is summarized in a contingency table. Conduct a ChiSquare test to determine if there is a significant relationship between product satisfaction levels and
#customer regions.
"""Sample data:
python
#Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])"""

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([[50, 30, 40, 20],   # Satisfied
                 [30, 40, 30, 50],   # Neutral
                 [20, 30, 40, 30]])  # Dissatisfied

# Perform Chi-Square test
chi2_stat, p_val, dof, expected = chi2_contingency(data)

print("Chi-Square Statistic:", chi2_stat)
print("P-Value:", p_val)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)

# Interpret the results
alpha = 0.05
if p_val < alpha:
    print("\nThere is a significant relationship between product satisfaction levels and customer regions.")
else:
    print("\nThere is no significant relationship between product satisfaction levels and customer regions.")
# Out:
# Chi-Square Statistic: 27.777056277056275
# P-Value: 0.00010349448486004387
# Degrees of Freedom: 6
# Expected Frequencies:
# [[34.14634146 34.14634146 37.56097561 34.14634146]
#  [36.58536585 36.58536585 40.24390244 36.58536585]
#  [29.26829268 29.26829268 32.19512195 29.26829268]]
#
# There is a significant relationship between product satisfaction levels and customer regions.

# %%
#23 A company implemented an employee training program to improve job performance (Effective, Neutral, Ineffective). After the training, they collected data from a sample of employees and classified them based on their job performance before and after the training. Perform a Chi-Square test to determine if there is a significant difference between job performance levels before and after the training.

"""Sample data:
python
# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])"""

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20],   # Effective
                 [30, 40, 30],   # Neutral
                 [20, 30, 40]])  # Ineffective

# Perform Chi-Square test
chi2_stat, p_val, dof, expected = chi2_contingency(data)

print("Chi-Square Statistic:", chi2_stat)
print("P-Value:", p_val)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:")
print(expected)

# Interpret the results
alpha = 0.05
if p_val < alpha:
    print("\nThere is a significant difference between job performance levels before and after training.")
else:
    print("\nThere is no significant difference between job performance levels before and after training.")
# Out:
# Chi-Square Statistic: 22.161728395061726
# P-Value: 0.00018609719479882557
# Degrees of Freedom: 4
# Expected Frequencies:
# [[34.48275862 34.48275862 31.03448276]
#  [34.48275862 34.48275862 31.03448276]
#  [31.03448276 31.03448276 27.93103448]]
#
# There is a significant difference between job performance levels before and after training.

# %%
 #24. A company produces three different versions of a product: Standard, Premium, and Deluxe. The company wants to determine if there is a significant difference in customer satisfaction scores among the three product versions. They conducted a survey and collected customer satisfaction scores for each version from a random sample of customers. 
 #Perform an ANOVA test to determine if there is a significant difference in customer satisfaction scores.
""" Use the following data:
  ```python
  # Sample data: Customer satisfaction scores for each product version
  standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
  premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
  deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]"""

import numpy as np
from scipy.stats import f_oneway

# Sample data: Customer satisfaction scores for each product version
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(standard_scores, premium_scores, deluxe_scores)

print("F-Statistic:", f_statistic)
print("P-Value:", p_value)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("\nThere is a significant difference in customer satisfaction scores among the product versions.")
else:
    print("\nThere is no significant difference in customer satisfaction scores among the product versions.")
# Out:
# F-Statistic: 27.03556231003039
# P-Value: 3.5786328857349003e-07
#
# There is a significant difference in customer satisfaction scores among the product versions.
